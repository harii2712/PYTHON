# %%
# Out:
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  Toyota
# Invalid choice!
#
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  Innova
# Invalid choice!
#
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  2500
# Invalid choice!
#
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  1
# Car Name:  Honda City
# Model:  city
# Rent/day:  2500
# Car added successfully!
#
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  honda
# Invalid choice!
#
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  city
# Invalid choice!
#
# === Car Rental System ===
# 1. Add Car
# 2. View Cars
# 3. Rent Car
# 4. Return Car
# 5. Exit
# Choose:  2000
# Invalid choice!
#
# ...

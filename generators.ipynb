# %%
# GENERATORS ONE BY ONE WORK


def gen(n):
    while n>0:
        yield n 
        n=n-1

for i in gen(5):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
#ITERATOR   NEXT BY NEXT WORK

l=[1,2,3,4,5]
it=iter(l)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s=[x**2 for x in range(1,6)]
print(s)
# Out:
# [1, 4, 9, 16, 25]

# %%
s={x:x**2 for x in range (1,6)}
print(s)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
#IMPORT RE REGULAR EXPERSSION
import re
text = "the rain in india"
n = re.sub(r'rain','snow',text)
print(n)
# Out:
# the snow in india

# %%
import re
text = "the rain in india"
n=re.match(r'^t',text)
print(bool(n))
# Out:
# True

# %%
def append_to(element, to=[]):
    to.append(element)
    return to

print(append_to(1))
print(append_to(2))
print(append_to(3, []))
print(append_to(4))
# Out:
# [1]
# [1, 2]
# [3]
# [1, 2, 4]

# %%
funcs = [lambda x=i: x for i in range(4)]
results = [f() for f in funcs]
print(results)
# Out:
# [0, 1, 2, 3]

# %%
def mystery(n):
    if n == 0:
        return 0
    else:
        return n + mystery(n - 1)

print(mystery(4))
# Out:
# 10

# %%
def get():    
    print("hai")
    get()
get()
# Out:
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# ...

# %%
def mystery(n):
    if n==0:
       return 0
    else :
        return n+m

# %%
x=5
def foo ():
    x=10
    return x
print(foo())
print(x)
# Out:
# 10
# 5

# %%
x=[1,2,3]
y=x
y[0]=100
print(x)
# Out:
# [100, 2, 3]

# %%
t=(1,2,[3,4])
t[2][0]=99
print(t)
# Out:
# (1, 2, [99, 4])

# %%
x={[1,2]:'a'}
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x={[1,2]:'a'}
#       2 print(x)
#
# TypeError: unhashable type: 'list'
